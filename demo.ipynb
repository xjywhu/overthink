# %%
from runner.main2 import Runner2

# %%
server = Runner2()

# %%
server.start("results/codegeneration/qwq-32b/lcb_generation.json", max_workers=10)
# Out:
# gpt-4o-mini: Processing Questions:   0%|          | 0/511 [00:00<?, ?it/s]
# Error in process_function for question 274: Error code: 400 - {'error': {'message': "The response was filtered due to the prompt triggering Azure OpenAI's content management policy. Please modify your prompt and retry. To learn more about our content filtering policies please read our documentation: https://go.microsoft.com/fwlink/?linkid=2198766 (request id: 2025041104534886711953808319263)", 'type': '', 'param': '', 'code': None}}
# Traceback (most recent call last):
#   File "/Users/starphesu/Code/overthink/runner/main2.py", line 110, in process_function
#     response = self.run_demo(question)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/starphesu/Code/overthink/runner/main2.py", line 92, in run_demo
#     response = self.model.chat(input_prompt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/starphesu/Code/overthink/llm/openai_api.py", line 92, in chat
# ...
