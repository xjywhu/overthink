# %%
from runner.main2 import Runner2

# %%
server = Runner2()

# %%
server.start("results/codeexecution/QwQ-32B/demo.json", max_workers=10)
# Out:
# gpt-4o-mini: Processing Questions:   0%|          | 0/479 [00:00<?, ?it/s]
